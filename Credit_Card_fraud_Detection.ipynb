# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
credit_data=pd.read_csv('D:\\Credit_fruad_detection\\creditcard.csv')
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.set_option('display.max_row',None)
pd.set_option('display.max_columns',None)
print(credit_data.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
credit_data.shape
# Out:
# (284807, 31)

# %%
print(credit_data['Class'].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=credit_data,x='Amount',bins=50,kde=True)
plt.title('Distribution of amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=credit_data,x='Class',bins=60,kde=True)
plt.title('Destribution of class 0 and 1')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=credit_data,x='Class',y='Amount',palette='Set2')
plt.title('violinplot of amount by class')
plt.xlabel('Class')
plt.ylabel('Amount')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=credit_data,x='Class')
plt.title('Boxplot of class 0 and 1')
plt.xlabel('Class')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=credit_data,x='Class')
plt.title('Distribution of 0 and 1')
plt.xlabel('Class')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
credit_data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
numerical_feature=credit_data.select_dtypes(include=['float64','int64']).columns.tolist()
for feature in numerical_feature:
    plt.figure(figsize=(8,6))
    sns.histplot(data=credit_data,x=feature,bins=50,kde=True)
    plt.title('Distribution of numerical feature ')
    plt.xlabel(feature)
    plt.show()

# %%
credit_data['Class'].isnull().sum()
# Out:
# 0

# %%
#Scaling time and Amount
scaled_inputs=StandardScaler()
credit_data[['Time','Amount']]=scaled_inputs.fit_transform(credit_data[['Time','Amount']])

# %%
credit_data.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9       V10       V11       V12       V13  \
# 0  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
#
#         V14       V15       V16       V17       V18       V19       V20  \
# ...

# %%
new_credit_data=credit_data.copy()
new_credit_data.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996583  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996562 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996562 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996541 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9       V10       V11       V12       V13  \
# 0  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
#
#         V14       V15       V16       V17       V18       V19       V20  \
# ...

# %%
#divide data fro inputes and targets:
x=new_credit_data.drop('Class',axis=1)
y=new_credit_data['Class']
#print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 4
#       2 x=new_credit_data.drop('Class',axis=1)
#       3 y=new_credit_data['Class']
# ----> 4 print(x)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1094, in DataFrame.__repr__(self)
#    1091     return buf.getvalue()
#    1093 repr_params = fmt.get_dataframe_repr_params()
# -> 1094 return self.to_string(**repr_params)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1271, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1252 with option_context("display.max_colwidth", max_colwidth):
#    1253     formatter = fmt.DataFrameFormatter(
#    1254         self,
#    1255         columns=columns,
#    (...)
# ...

# %%
#split the data into train test split method
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
model=RandomForestClassifier(random_state=45)
#train the model 
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=45)

# %%
#make the prediction:
y_prediction=model.predict(x_test)
y_prediction_probability=model.predict_proba(x_test)[:,1]
print(prediction)
# Out:
# [0 0 0 ... 0 0 0]

# %%
#Evaluating the model
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
# Confusion Matrix
print(confusion_matrix(y_test, y_prediction))

# Classification Report
print(classification_report(y_test, y_prediction))

# ROC-AUC Score
print(f'ROC-AUC Score: {roc_auc_score(y_test, y_prediction_probability)}')
# Out:
# [[56844     3]
#  [   19    96]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56847
#            1       0.97      0.83      0.90       115
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.92      0.95     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC Score: 0.9638192830335583

# %%
#!pip install graphviz
# Out:
# ...
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/00/be/d59db2d1d52697c6adc9eacaf50e8965b6345cc143f671e1ed068818d5cf/graphviz-0.20.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.1 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/47.1 kB 262.6 kB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 295.1 kB/s eta 0:00:00
# ...

# %%
from sklearn.tree import plot_tree

#extarcting a single tree:
tree=model.estimators_[0]
feature_names_list = list(x.columns)

plt.figure(figsize=(20,10))

plot_tree(
    tree,
    feature_names=feature_names_list,
    class_names=['Non Fraud','Fraud'],
    filled=True,
    rounded=True,
    proportion=True,
    fontsize=10
         )
plt.show()
